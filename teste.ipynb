# %%
# pytorch mlp for regression
from numpy import vstack
import numpy as np
from numpy import sqrt
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch import Tensor
from torch.nn import Linear
from torch.nn import Tanh
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD
from torch.optim import Adam
from torch.nn import MSELoss
from torch.nn.init import xavier_uniform_
 

with open('results.csv', 'a') as f:
    f.write('layer1,layer2,actFunc,learning,mse,mae\n') 
# dataset definition
class CSVDataset(Dataset):
    # load the dataset
    def __init__(self, path):
        # load the csv file as a dataframe
        df = read_csv(path, header=None)
        # store the inputs and outputs
        self.X = df.values[:, :-1].astype('float32')
        self.y = df.values[:, -1].astype('float32')
        # print(len(self.X[0]))
        # ensure target has the right shape
        self.y = self.y.reshape((len(self.y), 1))
        
    # number of rows in the dataset
    def __len__(self):
        return len(self.X)
 
    # get a row at an index
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]
 
    # get indexes for train and test rows
    def get_splits(self, n_test=0.20):
        # determine sizes
        test_size = round(n_test * len(self.X))
        train_size = len(self.X) - test_size
        # calculate the split
        return random_split(self, [train_size, test_size])
 
# model definition
class MLP(Module):
    # define model elements
    def __init__(self, n_inputs,layer1, layer2, act_func):
        super(MLP, self).__init__()
        # input to first hidden layer
        self.hidden1 = Linear(n_inputs, layer1)
        xavier_uniform_(self.hidden1.weight)
        self.act1 = act_func()
        # second hidden layer
        self.hidden2 = Linear(layer1, layer2)
        xavier_uniform_(self.hidden2.weight)
        self.act2 = act_func()
        # third hidden layer and output
        self.hidden3 = Linear(layer2, 1)
        xavier_uniform_(self.hidden3.weight)
 
    # forward propagate input
    def forward(self, X):
        # input to first hidden layer
        X = self.hidden1(X)
        X = self.act1(X)
         # second hidden layer
        X = self.hidden2(X)
        X = self.act2(X)
        # third hidden layer and output
        X = self.hidden3(X)
        return X
 
# prepare the dataset
def prepare_data(path):
    # load the dataset
    dataset = CSVDataset(path)
    # print(CSVDataset(path).__getitem__(0))
    # calculate split
    train, test = dataset.get_splits()
    # prepare data loaders
    train_dl = DataLoader(train, batch_size=32, shuffle=True)
    test_dl = DataLoader(test, batch_size=1024, shuffle=False)
    return train_dl, test_dl
 
# train the model
def train_model(train_dl, model, learn):
    # define the optimization
    criterion = MSELoss()
    optimizer = Adam(model.parameters(), lr=learn)
    # enumerate epochs
    for epoch in range(1000):
        # enumerate mini batches
        for i, (inputs, targets) in enumerate(train_dl):
            # clear the gradients
            optimizer.zero_grad()
            # compute the model output
            yhat = model(inputs)
            # calculate loss
            loss = criterion(yhat, targets)
            # credit assignment
            loss.backward()
            # update model weights
            optimizer.step()
 
# evaluate the model
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    for i, (inputs, targets) in enumerate(test_dl):
        # evaluate the model on the test set
        yhat = model(inputs)
        # retrieve numpy array
        yhat = yhat.detach().numpy()
        actual = targets.numpy()
        actual = actual.reshape((len(actual), 1))
        # store
        predictions.append(yhat)
        actuals.append(actual)
    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate mse
    mse = mean_squared_error(actuals, predictions)
    mae = mean_absolute_error(actuals, predictions)
    return mse, mae
 
# make a class prediction for one row of data
def predict(row, model):
    # convert row to data
    row = Tensor([row])
    # make prediction
    yhat = model(row)
    # retrieve numpy array
    yhat = yhat.detach().numpy()
    return yhat
 
# prepare the data
path = 'DataSet1 - Beacon1.csv'
train_dl, test_dl = prepare_data(path)
# print(len(train_dl.dataset), len(test_dl.dataset))

# %%
layers1 = [10,30,50,70,90]
layers2 = [10,30,50,70,90]
actFunc = [Sigmoid,Tanh,ReLU]
learning = [0.1,0.01,0.001,0.0001]
for a in layers1:
    for b in layers2:
        for c in actFunc:
            for d in learning:
                # define the network
                
                model = MLP(10,a, b, c)
                # train the model
                train_model(train_dl, model,d)
                # evaluate the model
                mse, mae = evaluate_model(test_dl, model)
                with open('results.csv', 'a') as f:
                    f.write(f'{a},{b},{c},{d},{mse},{mae}\n')
                print('MSE: %.3f, RMSE: %.3f' % (mse, sqrt(mse)))
                print('MAE: %.3f' % (mae))

                # make a single prediction (expect class=1)
                row = [-56,-54,-60,-54,-58,-60,-55,-59,-59,-54]
                yhat = predict(row, model)
                print('Predicted: %.3f' % yhat)
# Out:
# MSE: 3.299, RMSE: 1.816
# MAE: 1.591
# Predicted: 2.940
# MSE: 3.181, RMSE: 1.783
# MAE: 1.571
# Predicted: 3.256
# MSE: 2.441, RMSE: 1.562
# MAE: 1.278
# Predicted: 3.795
# MSE: 2.935, RMSE: 1.713
# MAE: 1.475
# Predicted: 3.773
# MSE: 3.186, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.366
# MSE: 3.182, RMSE: 1.784
# MAE: 1.567
# Predicted: 3.334
# MSE: 3.181, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.247
# MSE: 2.985, RMSE: 1.728
# MAE: 1.480
# Predicted: 4.086
# MSE: 3.187, RMSE: 1.785
# MAE: 1.573
# Predicted: 3.204
# MSE: 2.267, RMSE: 1.506
# MAE: 1.352
# Predicted: 4.300
# MSE: 1.987, RMSE: 1.410
# MAE: 1.179
# Predicted: 3.702
# MSE: 2.298, RMSE: 1.516
# MAE: 1.292
# Predicted: 3.850
# MSE: 3.201, RMSE: 1.789
# MAE: 1.563
# Predicted: 3.432
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.300
# MSE: 3.182, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.250
# MSE: 3.071, RMSE: 1.752
# MAE: 1.543
# Predicted: 3.446
# MSE: 3.290, RMSE: 1.814
# MAE: 1.589
# Predicted: 2.953
# MSE: 3.186, RMSE: 1.785
# MAE: 1.573
# Predicted: 3.209
# MSE: 3.182, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.244
# MSE: 2.797, RMSE: 1.673
# MAE: 1.440
# Predicted: 4.177
# MSE: 3.186, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.364
# MSE: 2.029, RMSE: 1.424
# MAE: 1.243
# Predicted: 3.972
# MSE: 1.668, RMSE: 1.292
# MAE: 0.999
# Predicted: 3.995
# MSE: 2.221, RMSE: 1.490
# MAE: 1.239
# Predicted: 3.476
# MSE: 3.185, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.355
# MSE: 3.183, RMSE: 1.784
# MAE: 1.567
# Predicted: 3.336
# MSE: 2.514, RMSE: 1.586
# MAE: 1.304
# Predicted: 3.707
# MSE: 2.662, RMSE: 1.632
# MAE: 1.392
# Predicted: 3.814
# MSE: 4.697, RMSE: 2.167
# MAE: 1.760
# Predicted: 4.517
# MSE: 3.203, RMSE: 1.790
# MAE: 1.563
# Predicted: 3.438
# MSE: 2.373, RMSE: 1.540
# MAE: 1.287
# Predicted: 4.071
# MSE: 3.180, RMSE: 1.783
# MAE: 1.568
# Predicted: 3.247
# MSE: 3.183, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.234
# MSE: 2.225, RMSE: 1.492
# MAE: 1.130
# Predicted: 3.221
# MSE: 2.007, RMSE: 1.417
# MAE: 1.141
# Predicted: 4.421
# MSE: 2.070, RMSE: 1.439
# MAE: 1.198
# Predicted: 3.517
# MSE: 3.181, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.251
# MSE: 3.186, RMSE: 1.785
# MAE: 1.572
# Predicted: 3.211
# MSE: 1.791, RMSE: 1.338
# MAE: 1.092
# Predicted: 3.982
# MSE: 2.750, RMSE: 1.658
# MAE: 1.402
# Predicted: 3.540
# MSE: 3.635, RMSE: 1.907
# MAE: 1.614
# Predicted: 3.960
# MSE: 3.219, RMSE: 1.794
# MAE: 1.561
# Predicted: 3.482
# MSE: 3.185, RMSE: 1.785
# MAE: 1.572
# Predicted: 3.212
# MSE: 3.117, RMSE: 1.765
# MAE: 1.556
# Predicted: 3.340
# MSE: 3.207, RMSE: 1.791
# MAE: 1.576
# Predicted: 3.121
# MSE: 2.066, RMSE: 1.438
# MAE: 1.130
# Predicted: 3.423
# MSE: 1.656, RMSE: 1.287
# MAE: 1.053
# Predicted: 5.003
# MSE: 1.956, RMSE: 1.398
# MAE: 1.172
# Predicted: 3.794
# MSE: 3.198, RMSE: 1.788
# MAE: 1.564
# Predicted: 3.420
# MSE: 3.180, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.267
# MSE: 1.830, RMSE: 1.353
# MAE: 1.123
# Predicted: 4.335
# MSE: 2.799, RMSE: 1.673
# MAE: 1.417
# Predicted: 3.335
# MSE: 4.090, RMSE: 2.022
# MAE: 1.719
# Predicted: 2.331
# MSE: 3.180, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.263
# MSE: 3.181, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.262
# MSE: 2.989, RMSE: 1.729
# MAE: 1.507
# Predicted: 3.749
# MSE: 3.183, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.228
# MSE: 1.993, RMSE: 1.412
# MAE: 1.213
# Predicted: 3.879
# MSE: 1.999, RMSE: 1.414
# MAE: 1.134
# Predicted: 3.659
# MSE: 2.219, RMSE: 1.490
# MAE: 1.266
# Predicted: 3.231
# MSE: 3.244, RMSE: 1.801
# MAE: 1.565
# Predicted: 3.539
# MSE: 3.196, RMSE: 1.788
# MAE: 1.564
# Predicted: 3.410
# MSE: 1.582, RMSE: 1.258
# MAE: 0.990
# Predicted: 4.077
# MSE: 2.719, RMSE: 1.649
# MAE: 1.394
# Predicted: 3.941
# MSE: 3.287, RMSE: 1.813
# MAE: 1.588
# Predicted: 2.959
# MSE: 3.193, RMSE: 1.787
# MAE: 1.574
# Predicted: 3.171
# MSE: 2.122, RMSE: 1.457
# MAE: 1.157
# Predicted: 4.298
# MSE: 2.791, RMSE: 1.671
# MAE: 1.390
# Predicted: 2.786
# MSE: 3.188, RMSE: 1.786
# MAE: 1.573
# Predicted: 3.194
# MSE: 2.147, RMSE: 1.465
# MAE: 1.127
# Predicted: 3.311
# MSE: 1.996, RMSE: 1.413
# MAE: 1.072
# Predicted: 4.254
# MSE: 2.170, RMSE: 1.473
# MAE: 1.276
# Predicted: 3.664
# MSE: 3.189, RMSE: 1.786
# MAE: 1.573
# Predicted: 3.191
# MSE: 3.262, RMSE: 1.806
# MAE: 1.581
# Predicted: 2.999
# MSE: 1.489, RMSE: 1.220
# MAE: 0.963
# Predicted: 4.242
# MSE: 2.654, RMSE: 1.629
# MAE: 1.381
# Predicted: 4.182
# MSE: 3.399, RMSE: 1.844
# MAE: 1.590
# Predicted: 3.753
# MSE: 3.180, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.276
# MSE: 1.984, RMSE: 1.408
# MAE: 1.151
# Predicted: 4.022
# MSE: 2.907, RMSE: 1.705
# MAE: 1.458
# Predicted: 3.549
# MSE: 3.193, RMSE: 1.787
# MAE: 1.574
# Predicted: 3.172
# MSE: 2.006, RMSE: 1.416
# MAE: 1.224
# Predicted: 3.926
# MSE: 1.820, RMSE: 1.349
# MAE: 1.142
# Predicted: 4.909
# MSE: 2.088, RMSE: 1.445
# MAE: 1.210
# Predicted: 3.710
# MSE: 3.214, RMSE: 1.793
# MAE: 1.577
# Predicted: 3.100
# MSE: 3.273, RMSE: 1.809
# MAE: 1.584
# Predicted: 2.981
# MSE: 1.710, RMSE: 1.308
# MAE: 1.079
# Predicted: 4.117
# MSE: 2.805, RMSE: 1.675
# MAE: 1.417
# Predicted: 3.490
# MSE: 3.209, RMSE: 1.791
# MAE: 1.576
# Predicted: 3.115
# MSE: 3.283, RMSE: 1.812
# MAE: 1.587
# Predicted: 2.965
# MSE: 2.213, RMSE: 1.488
# MAE: 1.235
# Predicted: 4.306
# MSE: 2.468, RMSE: 1.571
# MAE: 1.311
# Predicted: 3.425
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.298
# MSE: 2.021, RMSE: 1.422
# MAE: 1.236
# Predicted: 3.959
# MSE: 1.922, RMSE: 1.386
# MAE: 1.128
# Predicted: 4.475
# MSE: 2.275, RMSE: 1.508
# MAE: 1.322
# Predicted: 4.019
# MSE: 3.265, RMSE: 1.807
# MAE: 1.582
# Predicted: 2.993
# MSE: 3.213, RMSE: 1.792
# MAE: 1.577
# Predicted: 3.104
# MSE: 1.656, RMSE: 1.287
# MAE: 0.981
# Predicted: 4.121
# MSE: 2.769, RMSE: 1.664
# MAE: 1.409
# Predicted: 3.405
# MSE: 3.381, RMSE: 1.839
# MAE: 1.608
# Predicted: 2.837
# MSE: 3.184, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.222
# MSE: 1.512, RMSE: 1.230
# MAE: 0.930
# Predicted: 4.594
# MSE: 2.528, RMSE: 1.590
# MAE: 1.333
# Predicted: 3.838
# MSE: 3.181, RMSE: 1.783
# MAE: 1.571
# Predicted: 3.258
# MSE: 1.993, RMSE: 1.412
# MAE: 1.148
# Predicted: 3.589
# MSE: 2.128, RMSE: 1.459
# MAE: 1.088
# Predicted: 4.481
# MSE: 2.060, RMSE: 1.435
# MAE: 1.256
# Predicted: 4.456
# MSE: 3.520, RMSE: 1.876
# MAE: 1.631
# Predicted: 2.703
# MSE: 3.183, RMSE: 1.784
# MAE: 1.567
# Predicted: 3.344
# MSE: 1.545, RMSE: 1.243
# MAE: 1.029
# Predicted: 4.372
# MSE: 2.533, RMSE: 1.591
# MAE: 1.352
# Predicted: 3.980
# MSE: 3.620, RMSE: 1.903
# MAE: 1.613
# Predicted: 3.949
# MSE: 3.181, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.261
# MSE: 1.436, RMSE: 1.198
# MAE: 0.958
# Predicted: 4.205
# MSE: 2.574, RMSE: 1.604
# MAE: 1.337
# Predicted: 3.969
# MSE: 3.196, RMSE: 1.788
# MAE: 1.575
# Predicted: 3.157
# MSE: 1.985, RMSE: 1.409
# MAE: 1.203
# Predicted: 3.830
# MSE: 1.934, RMSE: 1.391
# MAE: 1.115
# Predicted: 4.024
# MSE: 2.212, RMSE: 1.487
# MAE: 1.199
# Predicted: 3.233
# MSE: 3.268, RMSE: 1.808
# MAE: 1.583
# Predicted: 2.988
# MSE: 3.182, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.240
# MSE: 1.415, RMSE: 1.189
# MAE: 0.956
# Predicted: 4.557
# MSE: 2.458, RMSE: 1.568
# MAE: 1.309
# Predicted: 3.819
# MSE: 3.297, RMSE: 1.816
# MAE: 1.591
# Predicted: 2.944
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.300
# MSE: 1.958, RMSE: 1.399
# MAE: 1.121
# Predicted: 4.468
# MSE: 2.668, RMSE: 1.633
# MAE: 1.383
# Predicted: 3.415
# MSE: 3.199, RMSE: 1.789
# MAE: 1.564
# Predicted: 3.424
# MSE: 2.069, RMSE: 1.438
# MAE: 1.131
# Predicted: 3.425
# MSE: 2.173, RMSE: 1.474
# MAE: 1.103
# Predicted: 3.455
# MSE: 2.105, RMSE: 1.451
# MAE: 1.213
# Predicted: 3.761
# MSE: 3.394, RMSE: 1.842
# MAE: 1.589
# Predicted: 3.748
# MSE: 3.185, RMSE: 1.785
# MAE: 1.572
# Predicted: 3.217
# MSE: 1.358, RMSE: 1.166
# MAE: 0.963
# Predicted: 4.563
# MSE: 2.453, RMSE: 1.566
# MAE: 1.303
# Predicted: 3.811
# MSE: 3.845, RMSE: 1.961
# MAE: 1.646
# Predicted: 4.101
# MSE: 3.216, RMSE: 1.793
# MAE: 1.561
# Predicted: 3.475
# MSE: 1.634, RMSE: 1.278
# MAE: 1.034
# Predicted: 4.574
# MSE: 2.533, RMSE: 1.592
# MAE: 1.321
# Predicted: 3.220
# MSE: 3.181, RMSE: 1.784
# MAE: 1.568
# Predicted: 3.319
# MSE: 2.049, RMSE: 1.431
# MAE: 1.160
# Predicted: 3.501
# MSE: 1.789, RMSE: 1.338
# MAE: 1.059
# Predicted: 3.983
# MSE: 2.060, RMSE: 1.435
# MAE: 1.173
# Predicted: 3.665
# MSE: 3.230, RMSE: 1.797
# MAE: 1.579
# Predicted: 3.061
# MSE: 3.248, RMSE: 1.802
# MAE: 1.566
# Predicted: 3.546
# MSE: 1.783, RMSE: 1.335
# MAE: 1.037
# Predicted: 3.942
# MSE: 2.367, RMSE: 1.538
# MAE: 1.272
# Predicted: 4.060
# MSE: 3.720, RMSE: 1.929
# MAE: 1.624
# Predicted: 4.020
# MSE: 3.238, RMSE: 1.799
# MAE: 1.579
# Predicted: 3.045
# MSE: 2.042, RMSE: 1.429
# MAE: 1.185
# Predicted: 4.225
# MSE: 2.359, RMSE: 1.536
# MAE: 1.265
# Predicted: 4.291
# MSE: 3.203, RMSE: 1.790
# MAE: 1.576
# Predicted: 3.135
# MSE: 2.037, RMSE: 1.427
# MAE: 1.135
# Predicted: 3.479
# MSE: 2.091, RMSE: 1.446
# MAE: 1.132
# Predicted: 4.825
# MSE: 2.079, RMSE: 1.442
# MAE: 1.200
# Predicted: 3.882
# MSE: 3.194, RMSE: 1.787
# MAE: 1.574
# Predicted: 3.166
# MSE: 3.183, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.227
# MSE: 1.552, RMSE: 1.246
# MAE: 0.967
# Predicted: 4.214
# MSE: 2.473, RMSE: 1.573
# MAE: 1.322
# Predicted: 3.781
# MSE: 4.066, RMSE: 2.017
# MAE: 1.679
# Predicted: 4.227
# MSE: 3.182, RMSE: 1.784
# MAE: 1.568
# Predicted: 3.327
# MSE: 2.128, RMSE: 1.459
# MAE: 1.149
# Predicted: 3.575
# MSE: 2.450, RMSE: 1.565
# MAE: 1.299
# Predicted: 3.483
# MSE: 3.192, RMSE: 1.787
# MAE: 1.565
# Predicted: 3.395
# MSE: 2.251, RMSE: 1.500
# MAE: 1.131
# Predicted: 3.192
# MSE: 2.230, RMSE: 1.493
# MAE: 1.141
# Predicted: 4.478
# MSE: 1.930, RMSE: 1.389
# MAE: 1.135
# Predicted: 3.737
# MSE: 3.181, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.260
# MSE: 3.189, RMSE: 1.786
# MAE: 1.565
# Predicted: 3.382
# MSE: 1.606, RMSE: 1.267
# MAE: 0.972
# Predicted: 4.352
# MSE: 2.472, RMSE: 1.572
# MAE: 1.299
# Predicted: 3.399
# MSE: 3.578, RMSE: 1.892
# MAE: 1.639
# Predicted: 2.655
# MSE: 3.223, RMSE: 1.795
# MAE: 1.561
# Predicted: 3.493
# MSE: 1.831, RMSE: 1.353
# MAE: 1.045
# Predicted: 3.999
# MSE: 2.432, RMSE: 1.559
# MAE: 1.296
# Predicted: 4.589
# MSE: 3.193, RMSE: 1.787
# MAE: 1.574
# Predicted: 3.171
# MSE: 2.221, RMSE: 1.490
# MAE: 1.129
# Predicted: 3.227
# MSE: 2.265, RMSE: 1.505
# MAE: 1.148
# Predicted: 5.338
# MSE: 2.034, RMSE: 1.426
# MAE: 1.131
# Predicted: 3.845
# MSE: 3.198, RMSE: 1.788
# MAE: 1.564
# Predicted: 3.420
# MSE: 3.181, RMSE: 1.784
# MAE: 1.571
# Predicted: 3.252
# MSE: 1.499, RMSE: 1.225
# MAE: 0.962
# Predicted: 4.364
# MSE: 2.289, RMSE: 1.513
# MAE: 1.238
# Predicted: 3.772
# MSE: 3.624, RMSE: 1.904
# MAE: 1.645
# Predicted: 2.619
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.303
# MSE: 1.350, RMSE: 1.162
# MAE: 0.942
# Predicted: 4.773
# MSE: 2.535, RMSE: 1.592
# MAE: 1.311
# Predicted: 3.795
# MSE: 3.199, RMSE: 1.788
# MAE: 1.575
# Predicted: 3.149
# MSE: 2.112, RMSE: 1.453
# MAE: 1.128
# Predicted: 3.356
# MSE: 1.830, RMSE: 1.353
# MAE: 1.106
# Predicted: 4.190
# MSE: 2.058, RMSE: 1.435
# MAE: 1.210
# Predicted: 3.562
# MSE: 3.186, RMSE: 1.785
# MAE: 1.573
# Predicted: 3.207
# MSE: 3.190, RMSE: 1.786
# MAE: 1.573
# Predicted: 3.187
# MSE: 1.455, RMSE: 1.206
# MAE: 0.982
# Predicted: 4.354
# MSE: 2.305, RMSE: 1.518
# MAE: 1.276
# Predicted: 3.904
# MSE: 3.772, RMSE: 1.942
# MAE: 1.662
# Predicted: 2.516
# MSE: 3.188, RMSE: 1.786
# MAE: 1.573
# Predicted: 3.195
# MSE: 2.027, RMSE: 1.424
# MAE: 1.122
# Predicted: 4.849
# MSE: 2.526, RMSE: 1.589
# MAE: 1.284
# Predicted: 4.315
# MSE: 3.185, RMSE: 1.785
# MAE: 1.567
# Predicted: 3.354
# MSE: 1.974, RMSE: 1.405
# MAE: 1.176
# Predicted: 3.734
# MSE: 1.889, RMSE: 1.374
# MAE: 1.086
# Predicted: 5.214
# MSE: 2.077, RMSE: 1.441
# MAE: 1.197
# Predicted: 3.831
# MSE: 3.185, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.359
# MSE: 3.195, RMSE: 1.788
# MAE: 1.564
# Predicted: 3.410
# MSE: 1.482, RMSE: 1.217
# MAE: 0.955
# Predicted: 4.634
# MSE: 2.318, RMSE: 1.522
# MAE: 1.272
# Predicted: 3.906
# MSE: 3.407, RMSE: 1.846
# MAE: 1.591
# Predicted: 3.762
# MSE: 3.204, RMSE: 1.790
# MAE: 1.576
# Predicted: 3.131
# MSE: 2.195, RMSE: 1.482
# MAE: 1.080
# Predicted: 4.727
# MSE: 2.388, RMSE: 1.545
# MAE: 1.269
# Predicted: 4.269
# MSE: 3.183, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.229
# MSE: 1.980, RMSE: 1.407
# MAE: 1.160
# Predicted: 3.655
# MSE: 1.560, RMSE: 1.249
# MAE: 0.983
# Predicted: 4.576
# MSE: 2.009, RMSE: 1.417
# MAE: 1.224
# Predicted: 4.242
# MSE: 3.251, RMSE: 1.803
# MAE: 1.566
# Predicted: 3.552
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.287
# MSE: 1.493, RMSE: 1.222
# MAE: 0.976
# Predicted: 4.196
# MSE: 2.029, RMSE: 1.424
# MAE: 1.187
# Predicted: 3.711
# MSE: 3.272, RMSE: 1.809
# MAE: 1.571
# Predicted: 3.588
# MSE: 3.289, RMSE: 1.814
# MAE: 1.574
# Predicted: 3.616
# MSE: 1.562, RMSE: 1.250
# MAE: 0.926
# Predicted: 5.109
# MSE: 2.460, RMSE: 1.569
# MAE: 1.290
# Predicted: 3.614
# MSE: 3.193, RMSE: 1.787
# MAE: 1.574
# Predicted: 3.173
# MSE: 2.070, RMSE: 1.439
# MAE: 1.131
# Predicted: 3.417
# MSE: 1.848, RMSE: 1.359
# MAE: 1.044
# Predicted: 5.358
# MSE: 2.009, RMSE: 1.417
# MAE: 1.212
# Predicted: 4.191
# MSE: 3.184, RMSE: 1.784
# MAE: 1.572
# Predicted: 3.219
# MSE: 3.232, RMSE: 1.798
# MAE: 1.579
# Predicted: 3.057
# MSE: 1.420, RMSE: 1.192
# MAE: 0.947
# Predicted: 4.687
# MSE: 2.284, RMSE: 1.511
# MAE: 1.286
# Predicted: 4.012
# MSE: 3.223, RMSE: 1.795
# MAE: 1.561
# Predicted: 3.494
# MSE: 3.186, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.360
# MSE: 2.131, RMSE: 1.460
# MAE: 1.206
# Predicted: 5.420
# MSE: 2.492, RMSE: 1.578
# MAE: 1.327
# Predicted: 3.362
# MSE: 3.199, RMSE: 1.789
# MAE: 1.575
# Predicted: 3.146
# MSE: 1.980, RMSE: 1.407
# MAE: 1.161
# Predicted: 3.651
# MSE: 2.129, RMSE: 1.459
# MAE: 1.116
# Predicted: 5.156
# MSE: 2.013, RMSE: 1.419
# MAE: 1.190
# Predicted: 4.463
# MSE: 3.254, RMSE: 1.804
# MAE: 1.581
# Predicted: 3.013
# MSE: 3.204, RMSE: 1.790
# MAE: 1.576
# Predicted: 3.132
# MSE: 1.381, RMSE: 1.175
# MAE: 0.944
# Predicted: 4.743
# MSE: 2.275, RMSE: 1.508
# MAE: 1.224
# Predicted: 3.546
# MSE: 3.208, RMSE: 1.791
# MAE: 1.576
# Predicted: 3.119
# MSE: 3.180, RMSE: 1.783
# MAE: 1.569
# Predicted: 3.298
# MSE: 1.993, RMSE: 1.412
# MAE: 1.104
# Predicted: 4.585
# MSE: 2.410, RMSE: 1.553
# MAE: 1.264
# Predicted: 4.007
# MSE: 3.223, RMSE: 1.795
# MAE: 1.578
# Predicted: 3.078
# MSE: 1.977, RMSE: 1.406
# MAE: 1.164
# Predicted: 3.681
# MSE: 1.892, RMSE: 1.376
# MAE: 1.119
# Predicted: 4.127
# MSE: 1.987, RMSE: 1.410
# MAE: 1.196
# Predicted: 3.999
# MSE: 3.646, RMSE: 1.909
# MAE: 1.647
# Predicted: 2.603
# MSE: 3.195, RMSE: 1.788
# MAE: 1.575
# Predicted: 3.161
# MSE: 1.486, RMSE: 1.219
# MAE: 0.944
# Predicted: 4.464
# MSE: 2.013, RMSE: 1.419
# MAE: 1.183
# Predicted: 4.085
# MSE: 3.248, RMSE: 1.802
# MAE: 1.566
# Predicted: 3.546
# MSE: 3.240, RMSE: 1.800
# MAE: 1.580
# Predicted: 3.040
# MSE: 1.421, RMSE: 1.192
# MAE: 0.923
# Predicted: 4.962
# MSE: 2.501, RMSE: 1.581
# MAE: 1.316
# Predicted: 4.831
# MSE: 3.181, RMSE: 1.784
# MAE: 1.568
# Predicted: 3.324
# MSE: 2.442, RMSE: 1.563
# MAE: 1.146
# Predicted: 3.031
# MSE: 1.729, RMSE: 1.315
# MAE: 1.005
# Predicted: 4.622
# MSE: 2.196, RMSE: 1.482
# MAE: 1.291
# Predicted: 4.431
# MSE: 3.401, RMSE: 1.844
# MAE: 1.590
# Predicted: 3.756
# MSE: 3.310, RMSE: 1.819
# MAE: 1.594
# Predicted: 2.925
# MSE: 1.494, RMSE: 1.222
# MAE: 1.036
# Predicted: 4.569
# MSE: 2.034, RMSE: 1.426
# MAE: 1.208
# Predicted: 4.332
# MSE: 3.186, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.362
# MSE: 3.181, RMSE: 1.784
# MAE: 1.568
# Predicted: 3.323
# MSE: 1.471, RMSE: 1.213
# MAE: 0.971
# Predicted: 4.709
# MSE: 2.301, RMSE: 1.517
# MAE: 1.217
# Predicted: 3.702
# MSE: 3.186, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.361
# MSE: 2.067, RMSE: 1.438
# MAE: 1.131
# Predicted: 3.424
# MSE: 1.907, RMSE: 1.381
# MAE: 1.065
# Predicted: 4.361
# MSE: 1.958, RMSE: 1.399
# MAE: 1.165
# Predicted: 4.123
# MSE: 4.028, RMSE: 2.007
# MAE: 1.709
# Predicted: 2.365
# MSE: 3.180, RMSE: 1.783
# MAE: 1.570
# Predicted: 3.269
# MSE: 1.678, RMSE: 1.295
# MAE: 0.974
# Predicted: 3.933
# MSE: 1.830, RMSE: 1.353
# MAE: 1.120
# Predicted: 4.190
# MSE: 3.262, RMSE: 1.806
# MAE: 1.581
# Predicted: 2.999
# MSE: 3.291, RMSE: 1.814
# MAE: 1.574
# Predicted: 3.618
# MSE: 1.889, RMSE: 1.374
# MAE: 0.965
# Predicted: 5.305
# MSE: 2.412, RMSE: 1.553
# MAE: 1.262
# Predicted: 4.853
# MSE: 3.187, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.370
# MSE: 1.997, RMSE: 1.413
# MAE: 1.215
# Predicted: 3.884
# MSE: 1.901, RMSE: 1.379
# MAE: 1.051
# Predicted: 5.901
# MSE: 1.896, RMSE: 1.377
# MAE: 1.162
# Predicted: 4.082
# MSE: 3.203, RMSE: 1.790
# MAE: 1.576
# Predicted: 3.134
# MSE: 3.200, RMSE: 1.789
# MAE: 1.575
# Predicted: 3.142
# MSE: 1.640, RMSE: 1.281
# MAE: 0.991
# Predicted: 4.756
# MSE: 2.187, RMSE: 1.479
# MAE: 1.216
# Predicted: 3.972
# MSE: 3.595, RMSE: 1.896
# MAE: 1.641
# Predicted: 2.641
# MSE: 3.395, RMSE: 1.843
# MAE: 1.611
# Predicted: 2.821
# MSE: 1.654, RMSE: 1.286
# MAE: 1.007
# Predicted: 4.917
# MSE: 2.093, RMSE: 1.447
# MAE: 1.166
# Predicted: 3.871
# MSE: 3.187, RMSE: 1.785
# MAE: 1.566
# Predicted: 3.370
# MSE: 1.979, RMSE: 1.407
# MAE: 1.162
# Predicted: 3.662
# MSE: 2.379, RMSE: 1.543
# MAE: 1.151
# Predicted: 5.111
# MSE: 2.054, RMSE: 1.433
# MAE: 1.181
# Predicted: 4.058
