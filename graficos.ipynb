# %%
import csv
import numpy as np
with open('coordenadasx.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
row = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(int, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%1==0:
            break
    if len(inter)==0:
        break
    row.append(inter)
    inter = []
    i+=1

flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)
coordX = list(map(int, flat_list1))

# %%
import csv
import numpy as np
with open('coordenadasy.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
row = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(int, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%1==0:
            break
    if len(inter)==0:
        break
    row.append(inter)
    inter = []
    i+=1

flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)
coordY = list(map(int, flat_list1))

# %%
import csv
import numpy as np
with open('grafico - LTx.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
LTx = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%200==0:
            break
    if len(inter)==0:
        break
    LTx.append(inter)
    inter = []
    i+=1

# %%
import csv
import numpy as np
with open('grafico - LTy.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
LTy = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%200==0:
            break
    if len(inter)==0:
        break
    LTy.append(inter)
    inter = []
    i+=1

# %%
import csv
import numpy as np
with open('grafico - RTx.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
RTx = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%100==0:
            break
    if len(inter)==0:
        break
    RTx.append(inter)
    inter = []
    i+=1

# %%
import csv
import numpy as np
with open('grafico - RTy.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
RTy = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%100==0:
            break
    if len(inter)==0:
        break
    RTy.append(inter)
    inter = []
    i+=1

# %%
import csv
import numpy as np
with open('grafico - Rx.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
Rx = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%200==0:
            break
    if len(inter)==0:
        break
    Rx.append(inter)
    inter = []
    i+=1

# %%
import csv
import numpy as np
with open('grafico - Ry.csv','r') as b:
    reader = csv.reader(b)
    lis = list(reader)

inter =[]
Ry = []
flat_list1 = []
for xs in lis:
    for x in xs:
        flat_list1.append(x)

dist = list(map(float, flat_list1))
i=0
j=0
while i < len(dist):
    
    while j < len(dist):
        inter.append(dist[j])
        j+=1
        if j%200==0:
            break
    if len(inter)==0:
        break
    Ry.append(inter)
    inter = []
    i+=1

# %%
LTx21 = LTx[0]
LTx22 = LTx[1]
LTx23 = LTx[2]
LTx61 = LTx[3]
LTx62 = LTx[4]
LTx63 = LTx[5]
LTx91 = LTx[6]
LTx92 = LTx[7]
LTx93 = LTx[8]

LTy21 = LTy[0]
LTy61 = LTy[1]
LTy101 = LTy[2]
LTy22 = LTy[3]
LTy62 = LTy[4]
LTy102 = LTy[5]
LTy23 = LTy[6]
LTy63 = LTy[7]
LTy103 = LTy[8]
# ---------------------------------
RTx21 = RTx[0]
RTx22 = RTx[1]
RTx23 = RTx[2]
RTx61 = RTx[3]
RTx62 = RTx[4]
RTx63 = RTx[5]
RTx91 = RTx[6]
RTx92 = RTx[7]
RTx93 = RTx[8]

RTy21 = RTy[0]
RTy61 = RTy[1]
RTy101 = RTy[2]
RTy22 = RTy[3]
RTy62 = RTy[4]
RTy102 = RTy[5]
RTy23 = RTy[6]
RTy63 = RTy[7]
RTy103 = RTy[8]
# ---------------------------------
Rx21 = Rx[0]
Rx22 = Rx[1]
Rx23 = Rx[2]
Rx61 = Rx[3]
Rx62 = Rx[4]
Rx63 = Rx[5]
Rx91 = Rx[6]
Rx92 = Rx[7]
Rx93 = Rx[8]

Ry21 = Ry[0]
Ry61 = Ry[1]
Ry101 = Ry[2]
Ry22 = Ry[3]
Ry62 = Ry[4]
Ry102 = Ry[5]
Ry23 = Ry[6]
Ry63 = Ry[7]
Ry103 = Ry[8]
# --------------------------
coordX21 = coordX[0]
coordX22 = coordX[1]
coordX23 = coordX[2]
coordX61 = coordX[3]
coordX62 = coordX[4]
coordX63 = coordX[5]
coordX91 = coordX[6]
coordX92 = coordX[7]
coordX93 = coordX[8]

coordY21 = coordY[0]
coordY61 = coordY[1]
coordY101 = coordY[2]
coordY22 = coordY[3]
coordY62 = coordY[4]
coordY102 = coordY[5]
coordY23 = coordY[6]
coordY63 = coordY[7]
coordY103 = coordY[8]

# %%
import matplotlib.pyplot as plt



log = plt.scatter(LTx, LTy, c ="green",
			linewidths = 1,
			marker ="x",
			s = 50)

tril = plt.scatter(RTx, RTy, c ="yellow",
			linewidths = 1,
			marker ="x",
			edgecolor ="red",
			s = 50)

rede = plt.scatter(Rx, Ry, c ="red",
			linewidths = 1,
			marker ="x",
			s = 50)

point = plt.scatter(coordX, coordY, c ="black",
			linewidths = 1,
			marker ="o",
			s = 100)

plt.xlabel("X")
plt.ylabel("Y")
plt.legend((log,tril,rede,point),
           ('Log/Tril', 'RNA/Tril', 'RNA', 'Pontos Coleta'),
           scatterpoints=1,
           loc='upper center',bbox_to_anchor=(0.5, -0.15),
           ncol=4,
           fontsize=10)
plt.savefig("scatter.jpg")
plt.show()
# Out:
# C:\Users\leona\AppData\Local\Temp/ipykernel_5264/1331163433.py:10: UserWarning: You passed a edgecolor/edgecolors ('red') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   tril = plt.scatter(RTx, RTy, c ="yellow",

# %%
import matplotlib.pyplot as plt



log = plt.scatter(Rx21, Ry21, c ="green",
			linewidths = 1,
			marker ="x",
			s = 50)



log = plt.scatter(Rx23, Ry101, c ="blue",
			linewidths = 1,
			marker ="s",
			s = 50)

log = plt.scatter(Rx61, Ry22, c ="red",
			linewidths = 1,
			marker ="P",
			s = 50)

log = plt.scatter(Rx62, Ry62, c ="purple",
			linewidths = 1,
			marker ="d",
			s = 50)

log = plt.scatter(Rx63, Ry102, c ="brown",
			linewidths = 1,
			marker ="D",
			s = 50)

log = plt.scatter(Rx22, Ry61, c ="yellow",
			linewidths = 1,
			marker ="^",
			s = 50)

log = plt.scatter(Rx91, Ry23, c ="gray",
			linewidths = 1,
			marker ="*",
			s = 50)

log = plt.scatter(Rx92, Ry63, c ="pink",
			linewidths = 1,
			marker ="p",
			s = 50)

log = plt.scatter(Rx93, Ry103, c ="orange",
			linewidths = 1,
			marker ="1",
			s = 50)




log = plt.scatter(coordX21, coordY21, c ="green",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX22, coordY61, c ="yellow",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX23, coordY101, c ="blue",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX61, coordY22, c ="red",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX62, coordY62, c ="purple",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX63, coordY102, c ="brown",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)


log = plt.scatter(coordX91, coordY23, c ="gray",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX92, coordY63, c ="pink",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX93, coordY103, c ="orange",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)



plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
import matplotlib.pyplot as plt



log = plt.scatter(Rx21, Ry21, c ="green",
			linewidths = 1,
			marker ="x",
			s = 50)

log = plt.scatter(Rx22, Ry61, c ="yellow",
			linewidths = 1,
			marker ="^",
			s = 50)

log = plt.scatter(Rx23, Ry101, c ="blue",
			linewidths = 1,
			marker ="s",
			s = 50)



log = plt.scatter(coordX21, coordY21, c ="green",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX22, coordY61, c ="yellow",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX23, coordY101, c ="blue",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)
plt.xlim(1,10)
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
import matplotlib.pyplot as plt
log = plt.scatter(Rx61, Ry22, c ="red",
			linewidths = 1,
			marker ="P",
			s = 50)

log = plt.scatter(Rx62, Ry62, c ="purple",
			linewidths = 1,
			marker ="d",
			s = 50)

log = plt.scatter(Rx63, Ry102, c ="brown",
			linewidths = 1,
			marker ="D",
			s = 50)

log = plt.scatter(coordX61, coordY22, c ="red",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX62, coordY62, c ="purple",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX63, coordY102, c ="brown",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)
plt.xlim(1,10)
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
import matplotlib.pyplot as plt

log = plt.scatter(Rx91, Ry23, c ="gray",
			linewidths = 1,
			marker ="*",
			s = 50)

log = plt.scatter(Rx92, Ry63, c ="pink",
			linewidths = 1,
			marker ="p",
			s = 50)

log = plt.scatter(Rx93, Ry103, c ="orange",
			linewidths = 1,
			marker ="1",
			s = 50)

log = plt.scatter(coordX91, coordY23, c ="gray",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX92, coordY63, c ="pink",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)

log = plt.scatter(coordX93, coordY103, c ="orange",
			linewidths = 1,
			marker ="o",
			edgecolors='black',
			s = 50)
plt.xlim(1,10)
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
print(RTx21)
# Out:
# [4.66, 4.63, 4.28, 4.61, 4.39, 4.34, 4.47, 4.31, 4.24, 4.28, 4.35, 4.35, 4.35, 4.3, 4.6, 4.55, 4.33, 4.23, 4.46, 4.54, 4.43, 4.61, 4.44, 4.44, 4.61, 4.2, 4.47, 4.66, 4.42, 4.4, 4.44, 4.5, 4.46, 4.34, 4.34, 4.53, 4.6, 4.62, 4.56, 4.51, 4.63, 4.44, 4.61, 4.56, 4.64, 4.34, 4.51, 4.5, 4.58, 4.36, 4.36, 4.29, 4.35, 4.59, 4.52, 4.44, 4.46, 4.53, 4.49, 4.31, 4.34, 4.52, 4.43, 4.39, 4.44, 4.23, 4.35, 4.46, 4.39, 4.26, 4.23, 4.52, 4.44, 4.66, 4.46, 4.49, 4.5, 4.43, 4.55, 4.49, 4.33, 4.54, 4.5, 4.33, 4.39, 4.35, 4.61, 4.42, 4.32, 4.27, 4.4, 4.61, 4.46, 4.38, 4.53, 4.51, 4.43, 4.46, 4.29, 4.42]
